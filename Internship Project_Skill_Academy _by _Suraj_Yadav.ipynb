# %% [markdown]
# # Internship Project at Skill Academy by Suraj Yadav

# %% [markdown]
# ## Import relevant libraries

# %%
import pandas as pd
# pandas is aliased as pd
import numpy as np
# numpy is aliased as np
import matplotlib.pyplot as plt
# pyplot is aliased as plt
import seaborn as sns
# seaborn is aliased as sns
import warnings

warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Upload TSV and JSON file

# %%
# Read TSV file
order_data_df = pd.read_csv("C:/Users/Admin/Desktop/Dataset/Order.tsv", sep="\t")

# Read JSON file
order_breakdown_data_df = pd.read_json("C:/Users/Admin/Desktop/Dataset/Order_breakdown.json")

# %%
# showing top 5 rows of the order data
order_data_df.head()
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039     1-1-13        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313     1-3-13    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300     1-4-13  Devin Huddleston     Valence          France
# 3  BN-2011-2819714     1-4-13       Mary Parker  Birmingham  United Kingdom
# 4   AZ-2011-617423     1-5-13      Daniel Burke  Echirolles          France
#
#     Region      Segment Ship Date     Ship Mode                 State  \
# 0    North  Home Office    1-5-13  Economy Plus             Stockholm
# 1    North     Consumer    1-7-13       Economy               England
# 2  Central     Consumer    1-8-13       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate    1-9-13       Economy               England
# 4  Central  Home Office    1-7-13      Priority  Auvergne-Rhône-Alpes
#
#    Days to Ship
# 0             4
# 1             4
# 2             4
# 3             5
# ...

# %%
# print the columns of order_data_df
order_data_df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Days to Ship'],
#       dtype='object')

# %%
# showing top 5 row of the order breakdown data
order_breakdown_data_df.head()
# Out:
#           Order ID                           Product Name  Discount  \
# 0  BN-2011-7407039            Enermax Note Cards, Premium       0.5
# 1  AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0
# 2  AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0
# 3  BN-2011-2819714             Boston Markers, Easy-Erase       0.5
# 4  BN-2011-2819714            Eldon Folders, Single Width       0.5
#
#    Actual Discount  Sales  Profit  Quantity         Category Sub-Category
# 0             22.5     45     -26         3  Office Supplies        Paper
# 1              0.0    854     290         7        Furniture    Bookcases
# 2              0.0    140      21         3  Office Supplies          Art
# 3             13.5     27     -22         2  Office Supplies          Art
# 4              8.5     17      -1         2  Office Supplies      Storage

# %%
# print the columns of the order breakdown data
order_breakdown_data_df.columns
# Out:
# Index(['Order ID', 'Product Name', 'Discount', 'Actual Discount', 'Sales',
#        'Profit', 'Quantity', 'Category', 'Sub-Category'],
#       dtype='object')

# %% [markdown]
# Since the data is related, We'll want to merge the two DataFrames based on common columns. There we can see that "Order ID" column is common in both dataframe. Let's merge both dataframe on "Order ID" column.

# %% [markdown]
# ## Merge both dataframe

# %%
# Merge the DataFrames on 'Order ID'
merged_df = pd.merge(order_data_df, order_breakdown_data_df, on='Order ID')

# %%
merged_df.head()
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039     1-1-13        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313     1-3-13    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300     1-4-13  Devin Huddleston     Valence          France
# 3  BN-2011-2819714     1-4-13       Mary Parker  Birmingham  United Kingdom
# 4  BN-2011-2819714     1-4-13       Mary Parker  Birmingham  United Kingdom
#
#     Region      Segment Ship Date     Ship Mode                 State  \
# 0    North  Home Office    1-5-13  Economy Plus             Stockholm
# 1    North     Consumer    1-7-13       Economy               England
# 2  Central     Consumer    1-8-13       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate    1-9-13       Economy               England
# 4    North    Corporate    1-9-13       Economy               England
#
#    Days to Ship                           Product Name  Discount  \
# ...

# %% [markdown]
# ## Save the merge dataframe

# %%
# Save the merged DataFrame to a CSV file
merged_df.to_csv('merged_data.csv', index=False)

# %% [markdown]
# ## Load the merage dataframe

# %%
df=pd.read_csv("merged_data.csv")
df.head() ## displaying the top 5 row of merged dataframe
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039     1-1-13        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313     1-3-13    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300     1-4-13  Devin Huddleston     Valence          France
# 3  BN-2011-2819714     1-4-13       Mary Parker  Birmingham  United Kingdom
# 4  BN-2011-2819714     1-4-13       Mary Parker  Birmingham  United Kingdom
#
#     Region      Segment Ship Date     Ship Mode                 State  \
# 0    North  Home Office    1-5-13  Economy Plus             Stockholm
# 1    North     Consumer    1-7-13       Economy               England
# 2  Central     Consumer    1-8-13       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate    1-9-13       Economy               England
# 4    North    Corporate    1-9-13       Economy               England
#
#    Days to Ship                           Product Name  Discount  \
# ...

# %%
df.tail()  ## printing last 5 row of the merged dataframe
# Out:
#              Order ID Order Date        Customer Name       City  \
# 8042  AZ-2014-1412225   12-31-16          Leon Barnes  Worcester
# 8043  AZ-2014-7604524   12-31-16  Rebecca Chamberlain    Hamburg
# 8044  BN-2014-4140795   12-31-16      Daniel Hamilton  Eindhoven
# 8045  BN-2014-4140795   12-31-16      Daniel Hamilton  Eindhoven
# 8046  BN-2014-4140795   12-31-16      Daniel Hamilton  Eindhoven
#
#              Country   Region      Segment Ship Date     Ship Mode  \
# 8042  United Kingdom    North     Consumer    1-1-17      Priority
# 8043         Germany  Central  Home Office    1-4-17       Economy
# 8044     Netherlands  Central  Home Office    1-5-17  Economy Plus
# 8045     Netherlands  Central  Home Office    1-5-17  Economy Plus
# 8046     Netherlands  Central  Home Office    1-5-17  Economy Plus
#
#               State  Days to Ship                       Product Name  \
# 8042        England             1    Fellowes Shelving, Single Width
# ...

# %%
df.shape # showing the shape of the dataframe
# Out:
# (8047, 19)

# %%
df.sample(6)   ## displaying 6 random sample form merged dataset
# Out:
#              Order ID Order Date    Customer Name              City  \
# 5263  AZ-2013-5764612    12-8-15     Claire Dilke            Meudon
# 6862  AZ-2014-7978715    8-25-16    Jeffrey Laird          Dewsbury
# 1770  BN-2012-9894081    3-30-14  Ben Summerville           Limoges
# 2224  BN-2012-9869476    7-14-14      Alexis Code             Turin
# 6146  BN-2014-2557638    5-26-16  Laura Elizabeth           Treviso
# 3201  AZ-2012-5728837   12-15-14    Edward Webber  Faches-Thumesnil
#
#              Country   Region      Segment Ship Date     Ship Mode  \
# 5263          France  Central     Consumer  12-11-15      Priority
# 6862  United Kingdom    North    Corporate   8-28-16  Economy Plus
# 1770          France  Central     Consumer    4-3-14       Economy
# 2224           Italy    South    Corporate   7-18-14       Economy
# 6146           Italy    South     Consumer   5-28-16  Economy Plus
# 3201          France  Central  Home Office  12-17-14  Economy Plus
#
# ...

# %% [markdown]
# ## Data PreProcessing

# %%
df.columns  ## Displaying the columns of merged dataframe
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Days to Ship',
#        'Product Name', 'Discount', 'Actual Discount', 'Sales', 'Profit',
#        'Quantity', 'Category', 'Sub-Category'],
#       dtype='object')

# %%
df.dtypes  ## Showing the datatypes of dataset
# Out:
# Order ID            object
# Order Date          object
# Customer Name       object
# City                object
# Country             object
# Region              object
# Segment             object
# Ship Date           object
# Ship Mode           object
# State               object
# Days to Ship         int64
# Product Name        object
# Discount           float64
# Actual Discount    float64
# Sales                int64
# Profit               int64
# Quantity             int64
# Category            object
# Sub-Category        object
# dtype: object

# %% [markdown]
# ###  Extract all categorical column

# %%
cat_col=df.select_dtypes(include="object").columns
cat_col
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Product Name',
#        'Category', 'Sub-Category'],
#       dtype='object')

# %% [markdown]
# ###  Extract all numerical column

# %%
num_col=df.select_dtypes(exclude="object").columns
num_col
# Out:
# Index(['Days to Ship', 'Discount', 'Actual Discount', 'Sales', 'Profit',
#        'Quantity'],
#       dtype='object')

# %% [markdown]
# ### Checking duplicated values

# %%
df.duplicated().sum()
# Out:
# 2

# %% [markdown]
# Here, we got 2 duplicated values. So, we will drop it

# %%
## Dropping duplicated values
df.drop_duplicates(inplace=True)

# %%
print(df.duplicated().any())
print(df.shape)
# Out:
# False
# (8045, 19)

# %% [markdown]
# Now, there is no duplicated values.

# %% [markdown]
# ### Checking Null Values

# %%
df.isnull().sum()
# Out:
# Order ID           0
# Order Date         0
# Customer Name      0
# City               0
# Country            0
# Region             0
# Segment            0
# Ship Date          0
# Ship Mode          0
# State              0
# Days to Ship       0
# Product Name       0
# Discount           0
# Actual Discount    0
# Sales              0
# Profit             0
# Quantity           0
# Category           0
# Sub-Category       0
# dtype: int64

# %% [markdown]
# Here, we can see that, there is no null values.

# %%
# Displaying the unique values in the dataset
df.nunique()
# Out:
# Order ID           4117
# Order Date         1214
# Customer Name       792
# City                999
# Country              15
# Region                3
# Segment               3
# Ship Date          1311
# Ship Mode             4
# State               127
# Days to Ship          8
# Product Name       1810
# Discount             14
# Actual Discount    1256
# Sales              1248
# Profit              845
# Quantity             14
# Category              3
# Sub-Category         17
# dtype: int64

# %%
## checking unique values of region column
df["Region"].unique()
# Out:
# array(['North', 'Central', 'South'], dtype=object)

# %%
## checking unique values of Segment column
df["Segment"].unique()
# Out:
# array(['Home Office', 'Consumer', 'Corporate'], dtype=object)

# %%
## checking unique values of ship mode column
df["Ship Mode"].unique()
# Out:
# array(['Economy Plus', 'Economy', 'Priority', 'Immediate'], dtype=object)

# %%
## checking unique values of days to ship column
df["Days to Ship"].unique()
# Out:
# array([4, 5, 2, 1, 6, 0, 7, 3], dtype=int64)

# %%
## checking unique values of Category column
df["Category"].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
## checking unique values of Sub-Category column
df["Sub-Category"].unique()
# Out:
# array(['Paper', 'Bookcases', 'Art', 'Storage', 'Fasteners', 'Binders',
#        'Tables', 'Labels', 'Chairs', 'Machines', 'Phones', 'Appliances',
#        'Supplies', 'Copiers', 'Envelopes', 'Accessories', 'Furnishings'],
#       dtype=object)

# %%
## checking unique values of Quantity column
df["Quantity"].unique()
# Out:
# array([ 3,  7,  2,  4,  1,  6,  5, 11,  8, 10, 12,  9, 14, 13],
#       dtype=int64)

# %% [markdown]
# As we seeing there are two columns name "Discount", "Actual Discount".So,, we will add both columns to make total discount.

# %%
df["Total Discount"]=df["Discount"]+df["Actual Discount"]
# As we made new column named "Total Discount". So, we can drop "discount" and "actual discount" column
df.drop(["Discount","Actual Discount"], axis=1, inplace=True)
df.head()
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039     1-1-13        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313     1-3-13    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300     1-4-13  Devin Huddleston     Valence          France
# 3  BN-2011-2819714     1-4-13       Mary Parker  Birmingham  United Kingdom
# 4  BN-2011-2819714     1-4-13       Mary Parker  Birmingham  United Kingdom
#
#     Region      Segment Ship Date     Ship Mode                 State  \
# 0    North  Home Office    1-5-13  Economy Plus             Stockholm
# 1    North     Consumer    1-7-13       Economy               England
# 2  Central     Consumer    1-8-13       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate    1-9-13       Economy               England
# 4    North    Corporate    1-9-13       Economy               England
#
#    Days to Ship                           Product Name  Sales  Profit  \
# ...

# %% [markdown]
# We will drop some columns like "Customer Name", "Product Name". We have not too much use.

# %%
## Drop customer name and product name columns
df.drop(["Customer Name","Product Name"],axis=1, inplace=True)

# %%
## We have to change the data type of order date and ship date
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %% [markdown]
# ### Extracting year from order date and ship ddatee

# %%
## Order Date
Order_Year=df["Order Date"].dt.year
df.drop("Order Date", axis=1, inplace=True)
df.insert(1, "Order Year", Order_Year)

## Ship Date
Ship_year=df["Ship Date"].dt.year
df.drop("Ship Date", axis=1, inplace=True)
df.insert(6, "Ship Year", Ship_year)

# %%
df.head()
# Out:
#           Order ID  Order Year        City         Country   Region  \
# 0  BN-2011-7407039        2013   Stockholm          Sweden    North
# 1  AZ-2011-9050313        2013   Southport  United Kingdom    North
# 2  AZ-2011-6674300        2013     Valence          France  Central
# 3  BN-2011-2819714        2013  Birmingham  United Kingdom    North
# 4  BN-2011-2819714        2013  Birmingham  United Kingdom    North
#
#        Segment  Ship Year     Ship Mode                 State  Days to Ship  \
# 0  Home Office       2013  Economy Plus             Stockholm             4
# 1     Consumer       2013       Economy               England             4
# 2     Consumer       2013       Economy  Auvergne-Rhône-Alpes             4
# 3    Corporate       2013       Economy               England             5
# 4    Corporate       2013       Economy               England             5
#
#    Sales  Profit  Quantity         Category Sub-Category  Total Discount
# ...

# %% [markdown]
# # Statistical Operation

# %%
## getting information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8045 entries, 0 to 8046
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        8045 non-null   object
#  1   Order Year      8045 non-null   int64
#  2   City            8045 non-null   object
#  3   Country         8045 non-null   object
#  4   Region          8045 non-null   object
#  5   Segment         8045 non-null   object
#  6   Ship Year       8045 non-null   int64
#  7   Ship Mode       8045 non-null   object
#  8   State           8045 non-null   object
#  9   Days to Ship    8045 non-null   int64
#  10  Sales           8045 non-null   int64
#  11  Profit          8045 non-null   int64
#  12  Quantity        8045 non-null   int64
#  13  Category        8045 non-null   object
#  14  Sub-Category    8045 non-null   object
#  15  Total Discount  8045 non-null   float64
# dtypes: float64(1), int64(6), object(9)
# memory usage: 1.0+ MB

# %%
## getting statistical data
df.describe()
# Out:
#         Order Year    Ship Year  Days to Ship        Sales       Profit  \
# count  8045.000000  8045.000000   8045.000000  8045.000000  8045.000000
# mean   2014.731137  2014.745059      4.006588   291.903170    35.202237
# std       1.100577     1.106922      1.740808   485.258616   178.147747
# min    2013.000000  2013.000000      0.000000     3.000000 -3060.000000
# 25%    2014.000000  2014.000000      3.000000    48.000000     1.000000
# 50%    2015.000000  2015.000000      4.000000   117.000000    14.000000
# 75%    2016.000000  2016.000000      5.000000   313.000000    47.000000
# max    2016.000000  2017.000000      7.000000  6517.000000  2476.000000
#
#           Quantity  Total Discount
# count  8045.000000     8045.000000
# mean      3.772281       29.910559
# std       2.203610       88.905064
# min       1.000000        0.000000
# 25%       2.000000        0.000000
# 50%       3.000000        0.000000
# 75%       5.000000       22.200000
# ...

# %%
## checking for outliers
df.boxplot()
plt.show()

# %%
## plotting a histplot
df.hist(figsize=(10,8))
plt.show()

# %% [markdown]
# ## EDA

# %%
a1=df["Region"].value_counts()
a1
# Out:
# Central    4425
# North      1811
# South      1809
# Name: Region, dtype: int64

# %%
plt.figure(figsize=(8,7))
plt.pie(a1.values,labels=a1.index, autopct="%.2f%%")
plt.title("Region Count % Distribution",fontsize=16)
plt.legend()
plt.show()

# %%
## Plotting a barplot for segment column
a2=df["Segment"].value_counts()
a2
# Out:
# Consumer       4173
# Corporate      2514
# Home Office    1358
# Name: Segment, dtype: int64

# %%
plt.figure(figsize=(8,7))
plt.bar(a2.index, a2.values)
plt.title("Distribution of Segment Column",fontsize=16)
plt.xlabel("Segment",fontsize=14)
plt.ylabel("Count",fontsize=14)
plt.show()

# %% [markdown]
# The Segment Consumer has the largest customer.

# %%
a3=df["Ship Mode"].value_counts()
a3
# Out:
# Economy         4860
# Economy Plus    1590
# Priority        1169
# Immediate        426
# Name: Ship Mode, dtype: int64

# %%
## Plotting a bar graph for Ship Mode column
plt.figure(figsize=(8,7))
colors=["Green","Cyan","Yellow","Blue"]
plt.bar(a3.index,a3.values, color=colors)
plt.title("Distribution of Ship Mode",fontsize=16)
plt.xlabel("Ship Mode",fontsize=12)
plt.ylabel("Count",fontsize=12)
#plt.grid()
plt.show()

# %% [markdown]
#  Economy is the most popular shipping mode.

# %%
b1=df["Category"].value_counts()
b1
# Out:
# Office Supplies    5284
# Technology         1523
# Furniture          1238
# Name: Category, dtype: int64

# %%
## plot a pie chart for Category column
plt.figure(figsize=(8,7))
plt.pie(b1.values,labels=b1.index,autopct="%.2f%%")
plt.title("Category %age Distribution", fontsize=16)
plt.legend()
plt.show()

# %% [markdown]
# Here. we can see that mostly region covered by office supplies(65.68%). The most selling category is office supplies

# %%
## Plotting a kde plot for Sales column
plt.figure(figsize=(8,7))
sns.histplot(x=df["Sales"],data=df,kde=True,color="Cyan")
plt.title("Distribution of Profit")
plt.show()

# %%
## Plotting a kde plot for Discount column
plt.figure(figsize=(8,7))
sns.histplot(x=df["Total Discount"],data=df,kde=True,color="Orange")
plt.title("Distribution of Discount")
plt.show()

# %%
## plotting a lineplot for quantity column
b1=df["Quantity"].value_counts()
print(b1)
plt.figure(figsize=(15,7))
sns.lineplot(x=b1.index,y=b1.values,marker="*",color="maroon")
plt.title("Distribution of Quantity")
plt.xlabel("Quantity")
plt.ylabel("Count")
plt.grid()
plt.show()
# Out:
# 3     1978
# 2     1971
# 4     1000
# 5      938
# 1      681
# 6      474
# 7      468
# 8      206
# 9      180
# 11      44
# 10      43
# 12      26
# 14      19
# 13      17
# Name: Quantity, dtype: int64

# %%
a2=df["Sub-Category"].value_counts().sort_values(ascending=False)
a2
# Out:
# Art            1151
# Binders        1058
# Storage        1051
# Phones          453
# Bookcases       391
# Furnishings     389
# Chairs          383
# Paper           374
# Labels          372
# Accessories     368
# Copiers         367
# Fasteners       350
# Supplies        347
# Envelopes       346
# Machines        335
# Appliances      235
# Tables           75
# Name: Sub-Category, dtype: int64

# %%
## Plotting a bar plot for sub-category
plt.figure(figsize=(8,8))
sns.barplot(a2.index,a2.values,palette="viridis")
plt.title("Distribution of sub-category",fontsize=16)
plt.xlabel("Sub-Category",fontsize=12)
plt.ylabel("COunt",fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Here, The top-selling sub-category are "Art", "Binders", "storage".

# %%
b3=df["Country"].value_counts()
b3
# Out:
# France            1916
# Germany           1640
# United Kingdom    1314
# Italy              979
# Spain              760
# Netherlands        393
# Austria            264
# Sweden             203
# Belgium            134
# Ireland            100
# Switzerland         78
# Norway              70
# Portugal            70
# Finland             64
# Denmark             60
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.bar(b3.index,b3.values,color="cyan")
plt.title("Count of Country",fontsize=16)
plt.xlabel("Country",fontsize=12)
plt.ylabel("Count",fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# #### Sales By Country Wise

# %%
a=df.groupby(["Country"])["Sales"].sum().sort_values(ascending=False)
a
# Out:
# Country
# France            609683
# Germany           488681
# United Kingdom    420497
# Italy             252742
# Spain             249318
# Austria            79382
# Netherlands        70313
# Belgium            42283
# Sweden             30490
# Switzerland        24874
# Finland            20702
# Norway             20529
# Ireland            15998
# Portugal           15106
# Denmark             7763
# Name: Sales, dtype: int64

# %%
plt.figure(figsize=(9,8))
a.plot(kind="bar", color=("m"))
plt.title("Sales By Country", fontsize=16)
plt.xlabel("Country",fontsize=12)
plt.ylabel("Sales",fontsize=12)
plt.xticks(rotation=90)
#plt.grid()
plt.show()

# %% [markdown]
# Here, we can see that majority of customers belongs from "France", "Germany", "United Kingdom".

# %% [markdown]
# #### Category wise sum of Profit

# %%
b=df.groupby(["Category"])["Profit"].sum()
b
# Out:
# Category
# Furniture           49734
# Office Supplies    124914
# Technology         108554
# Name: Profit, dtype: int64

# %%
colors=["yellow","lime","Cyan"]
plt.figure(figsize=(7,6))
plt.pie(b.values, labels=b.index, autopct="%.2f%%", colors=colors)
plt.title("Sum of Profit by Catefory Wise")
plt.legend(bbox_to_anchor=(1,1,0.1,-0.1))
plt.show()

# %% [markdown]
# More Profit Comes from Office Supplies Category

# %% [markdown]
# #### Discount by Category-wise

# %%
a4=df.groupby(["Category"])["Total Discount"].sum().sort_values(ascending=False)
a4
# Out:
# Category
# Furniture          86667.20
# Technology         83989.45
# Office Supplies    69973.80
# Name: Total Discount, dtype: float64

# %%
colors=["Magenta","lime","Gold"]
plt.figure(figsize=(7,6))
plt.pie(a4.values, labels=a4.index, autopct="%.2f%%", colors=colors)
plt.title("Discount by Category Wise")
plt.legend(bbox_to_anchor=(1,1,0.1,-0.1))
plt.show()

# %% [markdown]
# mostly discount leived on "Furniture", "Technology".

# %% [markdown]
# ### Sales By Order Year

# %%
plt.figure(figsize=(8,7))
plt.plot(df["Order Year"], df["Sales"], marker="o",color="Cyan")
plt.title("Sales by Order year", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Sales", fontsize=12)
plt.grid()
plt.show()

# %% [markdown]
# ### Sales By State Wise

# %%
c=df.groupby(["State"])["Sales"].sum().sort_values(ascending=False)
c
# Out:
# State
# England                       378984
# Ile-de-France                 230138
# North Rhine-Westphalia        170233
# Provence-Alpes-Côte d'Azur     81524
# Madrid                         57123
#                                ...
# Setúbal                          182
# Melilla                          145
# Basilicata                        86
# St. Gallen                        62
# Central Jutland                   34
# Name: Sales, Length: 127, dtype: int64

# %%
plt.figure(figsize=(19,18))
c.plot(kind="bar", color="violet")
plt.title("Sales By State Wise", fontsize=16)
plt.xlabel("State",fontsize=12)
plt.ylabel("Sales",fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Here, we can see that two states which have highest sales are "England","Ile-de-France ".

# %% [markdown]
# #### Sum of Profit by Sub-Category

# %%
a4=df.groupby(["Sub-Category"])["Profit"].sum().sort_values(ascending=False)
a4
# Out:
# Sub-Category
# Bookcases      43655
# Copiers        42775
# Appliances     37906
# Phones         27631
# Accessories    26830
# Art            23481
# Storage        21995
# Chairs         15489
# Binders        14675
# Furnishings    11321
# Machines       11318
# Paper           7485
# Supplies        6853
# Envelopes       6463
# Fasteners       3420
# Labels          2636
# Tables        -20731
# Name: Profit, dtype: int64

# %%
plt.figure(figsize=(10,9))
sns.barplot(a2.index,a2.values,palette="cividis")
plt.title("Profit by Sub-Category Wise",fontsize=16)
plt.xlabel("Sub-Category",fontsize=12)
plt.ylabel("Profit",fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Here. We can see that mostly Profit earned from top 3 sub-category "Art","Binders","Storage".

# %% [markdown]
# #### Discount by Sub-Category Wise

# %%
b2=df.groupby(["Sub-Category"])["Total Discount"].sum().sort_values(ascending=False)
b2
plt.figure(figsize=(9,8))
sns.barplot(b2.index, b2.values, palette="cool")
plt.title("Discount by Sub-Category wise",fontsize=16)
plt.xlabel("Sub-Category",fontsize=12)
plt.ylabel("Discount",fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Insights coming from this graph that mostly discount given on "Storage","Phones" Sub-Category.

# %% [markdown]
# ### Sales by Segement wise

# %%
c1=df.groupby(["Segment"])["Sales"].sum().sort_values(ascending=False)
c1
plt.figure(figsize=(6,5))
sns.barplot(c1.index, c1.values, palette="inferno")
plt.title("Sales by Segment Wise",fontsize=16)
plt.xlabel("Segment",fontsize=12)
plt.ylabel("Sales",fontsize=12)
plt.show()

# %% [markdown]
# Most of the custmors are from "Consumer" Segment

# %% [markdown]
# ### Profit by Segment Wise

# %%
c2=df.groupby(["Segment"])["Profit"].sum().sort_values(ascending=False)
c2
plt.bar(c2.index,c2.values,color="Gold")
plt.title("profit by Segment Wise",fontsize=16)
plt.xlabel("Segment",fontsize=12)
plt.ylabel("Profit",fontsize=12)
plt.show()

# %% [markdown]
# More profit earned by "Consumer" compare to others

# %% [markdown]
# #### Sales by Ship Mode

# %%
c3=df.groupby(["Ship Mode"])["Sales"].sum().sort_values(ascending=False)
c3
# Create the pie chart
plt.figure(figsize=(9,7))
plt.pie(c3, labels=c3.index, autopct='%1.1f%%')
plt.title('Percentage of Total Sales by Ship Mode')
plt.legend()
plt.show()

# %% [markdown]
# Economy Ship Mode has the highest Total Sales 60.2% in percentage

# %% [markdown]
# ### Profit by Order Year

# %%
b1=df.groupby("Order Year")["Profit"].sum().sort_values(ascending=False)
b1
plt.figure(figsize=(8,7))
sns.barplot(x=b1.index, y=b1.values, palette="Blues")
plt.title("Sum of Profit by Order Year", fontsize=16)
plt.xlabel("Order year", fontsize=12)
plt.ylabel("Profit", fontsize=12)
plt.show()

# %% [markdown]
# In 2016, profit is highest as per graph.

# %% [markdown]
# ### Average Profit with Discount

# %%
a=df[df["Total Discount"] > 0]["Profit"].mean()
a
# Out:
# -9.537603569152326

# %% [markdown]
# ### Average Profit without Discount

# %%
a=df[df["Total Discount"]==0]["Profit"].mean()
a
# Out:
# 63.813124108416545

# %% [markdown]
# ## Correlation

# %%
corr=df.corr()
corr
# Out:
#                 Order Year  Ship Year  Days to Ship     Sales    Profit  \
# Order Year        1.000000   0.994382     -0.002060  0.003289 -0.008412
# Ship Year         0.994382   1.000000      0.003581  0.003663 -0.007367
# Days to Ship     -0.002060   0.003581      1.000000 -0.004393  0.014172
# Sales             0.003289   0.003663     -0.004393  1.000000  0.441218
# Profit           -0.008412  -0.007367      0.014172  0.441218  1.000000
# Quantity         -0.000439  -0.000410      0.001623  0.353415  0.098664
# Total Discount   -0.000205  -0.000144     -0.018880  0.478413 -0.396261
#
#                 Quantity  Total Discount
# Order Year     -0.000439       -0.000205
# Ship Year      -0.000410       -0.000144
# Days to Ship    0.001623       -0.018880
# Sales           0.353415        0.478413
# Profit          0.098664       -0.396261
# Quantity        1.000000        0.206956
# Total Discount  0.206956        1.000000

# %%
## create a heatmap
sns.heatmap(corr,annot=True,cmap="cool")
plt.show()

# %%
sns.pairplot(df, hue="Sub-Category")
plt.show()

# %% [markdown]
# # Machine learning

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()

# %%
columns=["City","Country","Region","Segment","Ship Mode","State","Category","Sub-Category"]
for col in columns:
    df[col]=label_encoder.fit_transform(df[col])

# %%
df.head()
# Out:
#           Order ID  Order Year  City  Country  Region  Segment  Ship Year  \
# 0  BN-2011-7407039        2013   847       12       1        2       2013
# 1  AZ-2011-9050313        2013   841       14       1        0       2013
# 2  AZ-2011-6674300        2013   909        4       0        0       2013
# 3  BN-2011-2819714        2013   109       14       1        1       2013
# 4  BN-2011-2819714        2013   109       14       1        1       2013
#
#    Ship Mode  State  Days to Ship  Sales  Profit  Quantity  Category  \
# 0          1    103             4     45     -26         3         1
# 1          0     41             4    854     290         7         0
# 2          0      7             4    140      21         3         1
# 3          0     41             5     27     -22         2         1
# 4          0     41             5     17      -1         2         1
#
#    Sub-Category  Total Discount
# 0            12            23.0
# 1             4             0.0
# ...

# %% [markdown]
# # Selecting Dependent and Independent Variables

# %%
x=df.drop(["Order ID","Sales"], axis=1)
y=df["Sales"]
print(type(x))
print(type(y))
print(x.shape,y.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# (8045, 14) (8045,)

# %% [markdown]
# # Dividing the data into training and testing data

# %%
from sklearn.model_selection import train_test_split

# %%
print(0.2*8045)
print(8045-1609)
# Out:
# 1609.0
# 6436

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (6436, 14)
# (1609, 14)
# (6436,)
# (1609,)

# %% [markdown]
# # Creating a function to generate mean absolute error, mean squared error, root mean squared error, r2 score, and to compute training and testing score

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
def eval_metrics(y_test,y_pred):
    mae=mean_absolute_error(y_test,y_pred)
    mse=mean_squared_error(y_test,y_pred)
    rmse=np.sqrt(mean_squared_error(y_test,y_pred))
    r2=r2_score(y_test,y_pred)
    print("Mean Absolute Error:",mae)
    print("Mean Squared Error:",mse)
    print("Root Mean Squared Error:",rmse)
    print("R2 Score:",r2)
    
def mscore(model):
    print("Training Score:",model.score(x_train,y_train))
    print("Testing Score:",model.score(x_test,y_test))

# %% [markdown]
# # Applying Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
leg_reg=LinearRegression()
leg_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred_legreg=leg_reg.predict(x_test)
print(ypred_legreg[:20])
# Out:
# [ 231.02846666  225.34658676  238.97692683  100.08918347  940.36078762
#   166.90810063  503.83260554  290.46746972  107.8703521  1409.60095229
#   838.22537468  548.34088957  118.56183487  175.39559944  146.65960426
#   147.66469253 1290.30956156   38.35995715   56.28002655  303.68073814]

# %% [markdown]
# # Evaluation

# %%
eval_metrics(y_test,ypred_legreg)
# Out:
# Mean Absolute Error: 122.6683448337277
# Mean Squared Error: 52468.72882811831
# Root Mean Squared Error: 229.060535291696
# R2 Score: 0.7101509091257107

# %%
r2_scr_legreg=r2_score(y_test,ypred_legreg)
print(r2_scr_legreg)
# Out:
# 0.7101509091257107

# %%
mscore(leg_reg)
# Out:
# Training Score: 0.7202614946654189
# Testing Score: 0.7101509091257107

# %% [markdown]
# # KNN-Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
ypred_knn=knn.predict(x_test)
print(ypred_knn[:20])
# Out:
# [ 187.6  155.2  307.6   72.8 1590.2   85.2  437.2  104.2   80.8 1461.2
#   645.   175.8   69.6   88.    43.8   57.2  995.2   40.4   55.8  269.6]

# %% [markdown]
# # Evaluation

# %%
eval_metrics(y_test,ypred_knn)
# Out:
# Mean Absolute Error: 116.24226227470479
# Mean Squared Error: 50692.2600621504
# Root Mean Squared Error: 225.14941719256214
# R2 Score: 0.7199645232208634

# %%
r2_scr_knn=r2_score(y_test,ypred_knn)
print(r2_scr_knn)
# Out:
# 0.7199645232208634

# %%
mscore(knn)
# Out:
# Training Score: 0.8117953756126985
# Testing Score: 0.7199645232208634

# %% [markdown]
# # Ridge Regressor

# %%
from sklearn.linear_model import Ridge,Lasso

# %%
Rd=Ridge(alpha=0.2)
Rd.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.2)

# %%
ypred_rd=Rd.predict(x_test)
print(ypred_rd[:20])
# Out:
# [ 231.02403745  225.34752985  238.98209502  100.08648194  940.3598398
#   166.90619068  503.82601621  290.46849749  107.86896267 1409.59152163
#   838.22778631  548.33199204  118.55833862  175.39428516  146.65731681
#   147.66174631 1290.30507837   38.35750079   56.27828195  303.67930372]

# %% [markdown]
# # Evaluation

# %%
eval_metrics(y_test,ypred_rd)
# Out:
# Mean Absolute Error: 122.66659680587286
# Mean Squared Error: 52468.33818810675
# Root Mean Squared Error: 229.05968258972757
# R2 Score: 0.7101530671092323

# %%
r2_scr_rd=r2_score(y_test,ypred_rd)
print(r2_scr_rd)
# Out:
# 0.7101530671092323

# %%
mscore(Rd)
# Out:
# Training Score: 0.7202614934107829
# Testing Score: 0.7101530671092323

# %% [markdown]
# ## Lidge Regressor

# %%
Ls=Lasso(alpha=0.2)
Ls.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.2)

# %%
ypred_ls=Ls.predict(x_test)
print(ypred_ls[:20])
# Out:
# [ 230.56677763  225.17015494  239.82060526   99.66979813  939.79771665
#   167.00160172  502.25830894  290.53185726  107.50213693 1408.30275986
#   838.73580877  547.01101785  118.13533981  175.2089898   145.95750596
#   147.48156258 1289.50687058   38.53280812   55.82094843  303.16139721]

# %% [markdown]
# ## Evaluation

# %%
eval_metrics(y_test,ypred_ls)
# Out:
# Mean Absolute Error: 122.48299301955663
# Mean Squared Error: 52386.07288266261
# Root Mean Squared Error: 228.88004037631288
# R2 Score: 0.7106075192091028

# %%
r2_scr_ls=r2_score(y_test,ypred_ls)
print(r2_scr_ls)
# Out:
# 0.7106075192091028

# %%
mscore(Ls)
# Out:
# Training Score: 0.7202131777164812
# Testing Score: 0.7106075192091028

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor(n_estimators=100, max_depth=12, min_samples_split=10, random_state=1)
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=12, min_samples_split=10, random_state=1)

# %%
ypred_rf=rf.predict(x_test)
print(ypred_rf[:20])
# Out:
# [ 314.00045412  367.34767461  412.4602576    65.67709435 1439.74405284
#    78.98706601  443.89684583  365.25474702   72.65213479 1869.54657979
#  1116.30564377  310.92332922   61.07520399  118.49482545   48.93790822
#    74.71109228 1132.08915536   34.4445699    31.89301863  232.52121357]

# %% [markdown]
# ## Evaluation

# %%
eval_metrics(y_test,ypred_rf)
# Out:
# Mean Absolute Error: 86.09149191004535
# Mean Squared Error: 34208.88524618727
# Root Mean Squared Error: 184.95644148335919
# R2 Score: 0.8110224030600768

# %%
r2_scr_rf=r2_score(y_test,ypred_rf)
print(r2_scr_rf)
# Out:
# 0.8110224030600768

# %%
mscore(rf)
# Out:
# Training Score: 0.9170520989615776
# Testing Score: 0.8110224030600768

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor(max_depth=10, min_samples_split=12)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=10, min_samples_split=12)

# %%
ypred_dt=dt.predict(x_test)
print(ypred_dt[:20])
# Out:
# [ 268.59090909  846.75        510.48421053   76.67061611 1946.
#    85.98300971  304.35294118  343.05         76.67061611 1388.
#   784.375       294.03921569   42.72501412  161.49606299   42.72501412
#    85.98300971 1070.71428571   42.72501412   42.72501412  217.73376623]

# %% [markdown]
# ## Evaluation

# %%
eval_metrics(y_test,ypred_dt)
# Out:
# Mean Absolute Error: 96.2748550493729
# Mean Squared Error: 49113.28174659307
# Root Mean Squared Error: 221.6151658767808
# R2 Score: 0.7286871555296005

# %%
r2_scr_dt=r2_score(y_test,ypred_dt)
print(r2_scr_dt)
# Out:
# 0.7286871555296005

# %%
mscore(dt)
# Out:
# Training Score: 0.8813460703604863
# Testing Score: 0.7286871555296005

# %% [markdown]
# ## XGBoost

# %%
import xgboost as xgb

# %%
xgb=xgb.XGBRegressor(n_estimators=100, random_state=1)
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=1, ...)

# %%
ypred_xgb=xgb.predict(x_test)
print(ypred_xgb[:20])
# Out:
# [ 440.76855   279.41672   310.44833    75.38483  1608.158      67.5711
#   479.1471    348.0621     69.693474 1966.3729   1092.0327    211.01997
#    71.87791   107.12309    52.47941    81.066956  913.91766    52.30111
#    19.75343   217.64635 ]

# %% [markdown]
# ## Evaluation

# %%
eval_metrics(y_test,ypred_xgb)
# Out:
# Mean Absolute Error: 81.65029641426521
# Mean Squared Error: 28423.768422786205
# Root Mean Squared Error: 168.59350053541863
# R2 Score: 0.8429806930609153

# %%
r2_scr_xgb=r2_score(y_test, ypred_xgb)
print(r2_scr_xgb)
# Out:
# 0.8429806930609153

# %%
mscore(xgb)
# Out:
# Training Score: 0.9881845165533342
# Testing Score: 0.8429806930609153

# %% [markdown]
# ## Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbm=GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=1)
gbm.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(random_state=1)

# %%
ypred_gbm=gbm.predict(x_test)
print(ypred_gbm[:20])
# Out:
# [ 325.93391805  263.13110207  446.20059356   62.67492556 1463.22919795
#   101.45482357  491.61805131  269.65358094   66.57721773 1801.31859136
#  1037.05820528  322.64379529   85.7894312   132.88197529   63.64691049
#    88.63901729 1083.98694604   46.54255829   40.18529904  289.15932487]

# %% [markdown]
# ## Evaluation

# %%
eval_metrics(y_test,ypred_gbm)
# Out:
# Mean Absolute Error: 96.58467683092803
# Mean Squared Error: 35970.71213580403
# Root Mean Squared Error: 189.65946360728756
# R2 Score: 0.8012896739919462

# %%
r2_scr_gbm=r2_score(y_test,ypred_gbm)
print(r2_scr_gbm)
# Out:
# 0.8012896739919462

# %%
mscore(gbm)
# Out:
# Training Score: 0.8687012207526197
# Testing Score: 0.8012896739919462

# %% [markdown]
# ## SVR

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel='linear')  # You can choose the kernel type
svr.fit(x_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
ypred_svr=svr.predict(x_test)
print(ypred_svr)
# Out:
# [205.32255279 152.01602523 235.99847098 ...  49.72877015 411.51461856
#  378.0103581 ]

# %% [markdown]
# ## Evaluation

# %%
eval_metrics(y_test,ypred_svr)
# Out:
# Mean Absolute Error: 104.8179603116966
# Mean Squared Error: 53233.62484473447
# Root Mean Squared Error: 230.72413147465628
# R2 Score: 0.7059254510294066

# %%
r2_scr_svr=r2_score(y_test, ypred_svr)
print(r2_scr_svr)
# Out:
# 0.7059254510294066

# %%
mscore(svr)
# Out:
# Training Score: 0.7030046946857642
# Testing Score: 0.7059254510294066

# %% [markdown]
# ## Compare the models

# %%
Model=pd.DataFrame({"Models":["Linear Regression","KNN-Regressor","Ridge Regression","Lasso Regression","Random Forest Regressor","Decision Tree Regressor","XGBoost","Gradient Boosting Regressor","Support Vector Regression"],
                   "R2-Score":[r2_scr_legreg, r2_scr_knn, r2_scr_rd, r2_scr_ls, r2_scr_rf, r2_scr_dt, r2_scr_xgb, r2_scr_gbm, r2_scr_svr]})
Model
# Out:
#                         Models  R2-Score
# 0            Linear Regression  0.710151
# 1                KNN-Regressor  0.719965
# 2             Ridge Regression  0.710153
# 3             Lasso Regression  0.710608
# 4      Random Forest Regressor  0.811022
# 5      Decision Tree Regressor  0.728687
# 6                      XGBoost  0.842981
# 7  Gradient Boosting Regressor  0.801290
# 8    Support Vector Regression  0.705925

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(10,9))
sns.barplot(x=Model["Models"], y=Model["R2-Score"], palette="magma")
plt.title("Comparing the performance", fontsize=16)
plt.xticks(rotation=90)
plt.xlabel("Models", fontsize=12)
plt.ylabel("R2-Score", fontsize=12)
plt.show()

# %% [markdown]
# After comparison we can see that XGBoost is the best model as it acquire highest r2-score value (84%) as compare to others.

# %% [markdown]
# ## Final model (XGBoost) based on Evaluation from model_performance dataframe

# %%
import xgboost as xgb

# %%
xgb=xgb.XGBRegressor(n_estimators=100, random_state=1)
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=1, ...)

# %%
ypred_xgb=xgb.predict(x_test)
print(ypred_xgb[:20])
# Out:
# [ 440.76855   279.41672   310.44833    75.38483  1608.158      67.5711
#   479.1471    348.0621     69.693474 1966.3729   1092.0327    211.01997
#    71.87791   107.12309    52.47941    81.066956  913.91766    52.30111
#    19.75343   217.64635 ]

# %% [markdown]
# ## Save the Model

# %%
import pickle

# %%
pickle.dump(xgb, open("bst_model.pkl", "wb")) ## Saving the best performing model

# %% [markdown]
# ## Load the Model

# %%
loaded_model=pickle.load(open("bst_model.pkl", "rb"))

# %%
loaded_pred=loaded_model.predict(x_test)
print(loaded_pred[:20])
# Out:
# [ 440.76855   279.41672   310.44833    75.38483  1608.158      67.5711
#   479.1471    348.0621     69.693474 1966.3729   1092.0327    211.01997
#    71.87791   107.12309    52.47941    81.066956  913.91766    52.30111
#    19.75343   217.64635 ]

# %% [markdown]
# ## Taking some sample of 20 data points from original dataset

# %%
df1=df.sample(20)
df1
# Out:
#              Order ID  Order Year  City  Country  Region  Segment  Ship Year  \
# 492   BN-2011-4315830        2013    43        7       2        1       2013
# 4613  BN-2013-8210403        2015   182        5       0        1       2015
# 4202  AZ-2013-9746580        2015   505        5       0        0       2015
# 1513  BN-2012-7456673        2014   444        5       0        1       2014
# 7166  BN-2014-6976303        2016   102        5       0        0       2016
# 5387  BN-2013-9324448        2015   251        5       0        1       2015
# 5097  AZ-2013-7943122        2015   494        4       0        0       2015
# 1775  AZ-2012-9411069        2014   299        5       0        1       2014
# 3143  AZ-2012-3030732        2014   635        7       2        0       2014
# 5499  AZ-2014-2916681        2016   550        4       0        1       2016
# 6132  BN-2014-3618473        2016    78        8       0        0       2016
# ...

# %%
df1.shape  ## Shape of the data
# Out:
# (20, 16)

# %% [markdown]
# ## We have to save our data in csv file

# %%
df1.to_csv("sample_submission_sales.csv", index=False)

# %%
df2=pd.read_csv("sample_submission_sales.csv")
df2.head()
# Out:
#           Order ID  Order Year  City  Country  Region  Segment  Ship Year  \
# 0  BN-2011-4315830        2013    43        7       2        1       2013
# 1  BN-2013-8210403        2015   182        5       0        1       2015
# 2  AZ-2013-9746580        2015   505        5       0        0       2015
# 3  BN-2012-7456673        2014   444        5       0        1       2014
# 4  BN-2014-6976303        2016   102        5       0        0       2016
#
#    Ship Mode  State  Days to Ship  Sales  Profit  Quantity  Category  \
# 0          0     62             6    490    -114         4         1
# 1          3     68             3    119      50         6         1
# 2          0     93             7    680      60         9         0
# 3          3     81             2    435      87         3         0
# 4          0     15             4      6       3         1         1
#
#    Sub-Category  Total Discount
# 0            14           196.4
# 1             2             0.0
# ...

# %%
df2.shape  ## Shape of the data
# Out:
# (20, 16)

# %% [markdown]
# drop Order ID column as we don't need too much and we have to predict on same columns because I dropped Order ID column earlier.

# %%
df2.drop(["Order ID"], axis=1, inplace=True)

# %% [markdown]
# drop Sales Column also as we have to predict on independent data.

# %%
df2.drop("Sales", axis=1, inplace=True)

# %% [markdown]
# #### Now, going to predict....

# %%
xgb.predict(df2)
